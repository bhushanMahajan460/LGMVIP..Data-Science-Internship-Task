# %% [markdown]
# #### LetsGrowMore Data Science Internship
# #### Task3- Iris Flowers Classification ML Project
# #### Bhushan Mahajan
# #### LinkDin Profile ----> https://www.linkedin.com/in/bhushan-mahajan-506b26190/
# #### GitHub Profile ----> https://git.io/JzCts

# %%
#import libraries 

import numpy as np                         
import pandas as pd                         
import seaborn as sns                        
import matplotlib.pyplot as plt              
# %matplotlib inline

sns.set()

# %%
## regarding to ml this is the most famous dataset that is being initially used for solving a calssification problem 

iris = sns.load_dataset('iris')  
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
ax = iris.plot(figsize=(14,9),title="Iris Dataset" )
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
iris.plot(kind = 'hist', figsize=(14,9),title="Iris Dataset")
# Out:
# <AxesSubplot:title={'center':'Iris Dataset'}, ylabel='Frequency'>

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.drop(['species'],axis=1,inplace=True)
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
iris.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
iris.iloc[0].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
iris.iloc[0].plot.bar()
# Out:
# <AxesSubplot:>

# %%
iris.plot(figsize=(15,5),kind = 'hist',stacked=False,bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'hist', stacked = True, bins = 50, orientation = 'horizontal', figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 50, figsize=(15,5))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris['sepal_width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
iris.diff().hist(color='b',alpha=1,figsize=(15,5))
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
iris.plot.scatter(x='sepal_length',y='petal_length')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
iris.plot.scatter(figsize=(15,5),x='sepal_length',y='petal_length',c='sepal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
iris.plot.scatter(figsize=(17,5),x='sepal_length',y='petal_length',c='sepal_length',s=190,label='length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
iris.plot.hexbin(figsize=(17,5),x='sepal_length',y='petal_length',gridsize=5,C='sepal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df = iris.iloc[0]

# %%
df.plot.pie(figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='0'>

# %%
iris.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2

# %%
d=iris.head(3).T
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots=True,figsize=(20,20))
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
d.plot.pie(subplots=True,figsize=(20,20),fontsize=15,autopct='%.2f')
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
iris.plot(subplots=True,figsize=(15,8),sharex=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
iris.plot(subplots=True,figsize=(15,8),sharex=False,layout=(2,3))
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)
